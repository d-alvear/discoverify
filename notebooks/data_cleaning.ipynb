# %%
import pandas as pd
import numpy as np

import json
import requests
from IPython.display import clear_output

import psycopg2 as pg
conn = pg.connect(database="spotify_db",
                  user="postgres", 
                  password="damara1004")

def run_query(q):
    with conn:
        try:
            cur = conn.cursor()
            cur.execute(q)
            return pd.read_sql(q, conn)

        except (Exception, pg.DatabaseError) as error:
            print(error)

def run_command(c):
    with conn:
        try:
            cur = conn.cursor()
            cur.execute(c)
            cur.close()
            conn.commit()
            
        except (Exception, pg.DatabaseError) as error:
            print(error)

# %%
# reading in created datasets
track_metadata = pd.read_csv('../data/all_tracks_cleaned_V2.csv', index_col=0)
spotify_features = pd.read_csv('../data/audio_features_final.csv', index_col=0)

# %%
from ast import literal_eval
# reading in file of librosa features
with open('../data/results.txt') as f:
    features = [literal_eval(line.replace("\n","").rstrip(",")) for line in f]

# %%
librosa_features = pd.DataFrame(features, columns = features[0].keys())
librosa_features.head()
# Out:
#                  track_id  spectral_centroid  spectral_bandwidth      rolloff  \
# 0  000u1dTg7y1XCDXi80hbBX        2198.480202         2489.345784  4768.568760
# 1  003vvx7Niy0yvhvHt4a68B        2324.056734         2369.794157  4786.518665
# 2  005DVZaX9PuqQ5DHyr2BH3        2462.341196         2271.303356  4765.603560
# 3  007zAbR9EMRpOpBzbRcemz        1562.858037         1967.284586  3081.561739
# 4  008ELurRZpm5bv4T6J6vvR        1726.656428         1814.695628  3587.942825
#
#    zero_crossing_rate       mfcc1       mfcc2      mfcc3      mfcc4  \
# 0            0.082164 -136.455631   92.286567   4.411706  29.978968
# 1            0.105727  -65.774035   90.264960 -16.848465  32.145438
# 2            0.137565  -20.208630   83.652947 -39.032359  -1.407777
# 3            0.062572 -211.867577  121.315694   4.162437  33.818357
# 4            0.086967  -81.891582  126.597123 -35.135890  40.226285
#
#        mfcc5  ...         D        D#         E         F        F#         G  \
# 0   5.862119  ...  0.761796  0.583145  0.413551  0.281556  0.245734  0.229757
# 1   1.468458  ...  0.294782  0.289501  0.217538  0.532355  0.228859  0.202796
# 2 -18.297670  ...  0.249533  0.554072  0.287430  0.294211  0.190855  0.398437
# 3   5.821059  ...  0.363498  0.348780  0.382567  0.449853  0.352761  0.284755
# 4 -14.586352  ...  0.494739  0.333550  0.294227  0.370115  0.330995  0.416454
#
#          G#         A        A#         B
# 0  0.271889  0.330180  0.243558  0.315892
# 1  0.405416  0.195824  0.233053  0.165492
# 2  0.471000  0.228423  0.296749  0.238494
# 3  0.228843  0.235576  0.321313  0.308310
# 4  0.298092  0.394247  0.404228  0.301494
#
# [5 rows x 37 columns]

# %%
print(f"Metadata: {len(track_metadata)}; Spotify Features: {len(spotify_features)}; Librosa Features: {len(librosa_features)}")
# Out:
# Metadata: 230456; Spotify Features: 200006; Librosa Features: 17876

# %% [markdown]
# Still need to bring in librosa features that are already stored.

# %%
q = '''SELECT * FROM librosa_features'''

stored = run_query(q)
stored.head()
# Out:
#                  track_id  spectral_centroid  spectral_bandwidth    rolloff  \
# 0  6YDf6QV7QfCEo8O2dbWalK          1756.4558           2046.3342  3311.4383
# 1  0qaWxVVd3KrP4WY27KWpIe          1911.7354           2148.9760  4108.5335
# 2  1yZMv2GMAibgLGsQiowZrt          1502.5131           1782.0399  2969.3070
# 3  2eg2gvPXuwZ9FyrPaLgrXi          2430.0319           2420.7924  4922.0702
# 4  0wzruvvN7f5wu39aFcjTMw          2729.2951           2424.4074  5364.5676
#
#    zero_crossing_rate    mfcc1     mfcc2    mfcc3    mfcc4    mfcc5  ...  \
# 0              0.0825  -6.8987  128.4723 -26.9279  12.1849  20.8006  ...
# 1              0.0858 -43.1119  113.6926 -16.0353  21.3349  -7.6568  ...
# 2              0.0695 -73.8604  138.2465 -25.7173  24.4074  -0.4938  ...
# 3              0.1331  -8.5929   91.2195 -15.3536  17.1535  -0.0333  ...
# 4              0.1561  10.4661   73.9084 -32.9083   6.7778   1.7658  ...
#
#         D      D#       E       F      F#       G      G#       A      A#  \
# 0  0.4522  0.3723  0.5536  0.4106  0.4630  0.4977  0.4397  0.5498  0.3668
# 1  0.4439  0.2756  0.3617  0.2811  0.4238  0.5576  0.3802  0.5572  0.3689
# 2  0.2634  0.1774  0.4107  0.5217  0.2529  0.2749  0.2159  0.4378  0.1899
# 3  0.4748  0.2990  0.4744  0.3313  0.2653  0.3464  0.2482  0.3924  0.2739
# 4  0.2522  0.2841  0.5090  0.4800  0.6721  0.5047  0.5559  0.3559  0.2284
#
#         B
# 0  0.3736
# 1  0.4886
# 2  0.1266
# 3  0.4180
# 4  0.2586
#
# [5 rows x 37 columns]

# %% [markdown]
# Now I'll combine the dataframes.

# %%
combined_librosa = stored.append(librosa_features, ignore_index=True)
len(combined_librosa)
# Out:
# 46721

# %% [markdown]
# Still missing about 153,000 rows of librosa features, need to look into this.

# %%
# list of track ids that went through the librosa pipeline
librosa_ids = combined_librosa['track_id'].to_list()

# list of ids of that have spotify features, but did not go through the librosa pipeline
no_librosa = spotify_features[~spotify_features['id'].isin(librosa_ids)]['id'].to_list()

# finding which songs did not go through the librosa pipeline
track_metadata[track_metadata['track_id'].isin(no_librosa)]
# Out:
#                       track_id                                    track_name  \
# 30442   3tjFYV6RSFtuktYl3ZtYcq                        Mood (feat. Iann Dior)
# 30443   27u7t9d7ZQoyjsCROHuZJ3                    Tick Tock (feat. 24kGoldn)
# 30444   6piAUJJQFD8oHDUr0b7l7q                                     VALENTINO
# 30445   68UW3plyDDNg1dkNIZRezJ      Tinted Eyes (feat. blackbear & 24kGoldn)
# 30446   660BgHpKo1jhR9MMSFn7CF                     VALENTINO - Imanbek Remix
# ...                        ...                                           ...
# 230451  6jVVnTIC1zHFFdn2rBOE2g  This Must Be the Place (Naive Melody) - Live
# 230452  3xJ8siSD7r5mDqLNtQ5CPf                              A Soft Seduction
# 230453  6Mc0SvjQ2By4ZJWdF77M2C                             Dance on Vaseline
# 230454  392cd1euczCOcZAs0SvvZS           The Last Emperor (Main Title Theme)
# 230455  4MrwM9vGNeVKjIEtyZ2sQT                                  One Fine Day
#
#               artist               artist_id track_album_album_type  \
# 30442       24kGoldn  6fWVd57NKTalqvmjRd2t8Z                 single
# 30443   Clean Bandit  6MDME20pz9RveH9rEXvrOM                 single
# 30444       24kGoldn  6fWVd57NKTalqvmjRd2t8Z                  album
# 30445          DVBBS  5X4LWwbUFNzPkEas04uU82                 single
# 30446       24kGoldn  6fWVd57NKTalqvmjRd2t8Z                 single
# ...              ...                     ...                    ...
# 230451   David Byrne  20vuBdFblWUo2FCOvUzusB                  album
# 230452   David Byrne  20vuBdFblWUo2FCOvUzusB                  album
# 230453   David Byrne  20vuBdFblWUo2FCOvUzusB                  album
# 230454   David Byrne  20vuBdFblWUo2FCOvUzusB            compilation
# 230455   David Byrne  20vuBdFblWUo2FCOvUzusB                  album
#
#                 track_album_id                           track_album_name  \
# 30442   4YMnOf4a7obOcN1Gy2QEuM                     Mood (feat. Iann Dior)
# 30443   3tuAs968COA2vxKjiLvmxr                 Tick Tock (feat. 24kGoldn)
# 30444   2eLpj5EDUhyAoTks8sxcKR                      DROPPED OUTTA COLLEGE
# 30445   63qrRZqzJKieNXIbN2Uvkx   Tinted Eyes (feat. blackbear & 24kGoldn)
# 30446   2v44hAIsegAFzILiv6ghx8                  VALENTINO (Imanbek Remix)
# ...                        ...                                        ...
# 230451  1F4G3aGUoFejTCLPQ4tTgh                       Live From Austin, TX
# 230452  4tH7X5vlPeZclx8KNPNfE2                                   Feelings
# 230453  4tH7X5vlPeZclx8KNPNfE2                                   Feelings
# 230454  70iCI16xKlhPlJJT7OIKGH       The Last Emperor Original Soundtrack
# 230455  0mqvus9jydETK3A63iIG09  Everything That Happens Will Happen Today
#
#         track_duration_ms  track_popularity  \
# 30442            140525.0             100.0
# 30443            178373.0              86.0
# 30444            179133.0              80.0
# 30445            175081.0              73.0
# 30446            177975.0              70.0
# ...                   ...               ...
# 230451           350586.0              42.0
# 230452           181066.0              41.0
# 230453           308026.0              40.0
# 230454           241106.0              38.0
# 230455           293640.0              37.0
#
#                                         track_preview_url  \
# 30442   https://p.scdn.co/mp3-preview/45cb08fdb67744ab...
# 30443   https://p.scdn.co/mp3-preview/3d3f99ef7d4bea72...
# 30444   https://p.scdn.co/mp3-preview/6347fe20d7716220...
# 30445   https://p.scdn.co/mp3-preview/d198eb9b7ca39a5a...
# 30446   https://p.scdn.co/mp3-preview/9de5e13ff243c0e0...
# ...                                                   ...
# 230451  https://p.scdn.co/mp3-preview/98d44f14d88998fb...
# 230452  https://p.scdn.co/mp3-preview/b8c46ccfdce6b555...
# 230453  https://p.scdn.co/mp3-preview/879cb1d23da841d8...
# 230454                                                NaN
# 230455  https://p.scdn.co/mp3-preview/091069edb34425c1...
#
#                                                 subgenres    genre_1  \
# 30442                                        ['cali rap']   cali rap
# 30443   ['dance pop', 'edm', 'pop', 'post-teen pop', '...  dance pop
# 30444                                        ['cali rap']   cali rap
# 30445   ['big room', 'canadian electronic', 'dance pop...   big room
# 30446                                        ['cali rap']   cali rap
# ...                                                   ...        ...
# 230451  ['art pop', 'art punk', 'art rock', 'dance roc...    art pop
# 230452  ['art pop', 'art punk', 'art rock', 'dance roc...    art pop
# 230453  ['art pop', 'art punk', 'art rock', 'dance roc...    art pop
# 230454  ['art pop', 'art punk', 'art rock', 'dance roc...    art pop
# 230455  ['art pop', 'art punk', 'art rock', 'dance roc...    art pop
#
#                     genre_2    genre_3
# 30442                   NaN        NaN
# 30443                   edm        pop
# 30444                   NaN        NaN
# 30445   canadian electronic  dance pop
# 30446                   NaN        NaN
# ...                     ...        ...
# 230451             art punk   art rock
# 230452             art punk   art rock
# 230453             art punk   art rock
# 230454             art punk   art rock
# 230455             art punk   art rock
#
# [182127 rows x 14 columns]

# %% [markdown]
# It looks like not all song previews were downloaded when I ran the `get_mp3()` function. Songs that did not go through the pipeline do have preview links, so the problem is not that there are 153,000 songs without a preview, its just that the function didn't finish running.

# %%
subset = track_metadata[track_metadata['track_id'].isin(no_librosa)]
subset.reset_index(inplace=True, drop=True)

# a list of tuples to make it easier to get the mp3 files
songs = {subset.loc[i,'track_id'] : (subset.loc[i,'artist'], 
                                     subset.loc[i,'track_name'], 
                                     subset.loc[i,'track_preview_url']) 
         
         for i in range(0,len(subset))}

len(songs)
# Out:
# 182127

# %%
def get_missing_url(track_id, artist, song):
    '''falls back on the iTunes API to get a 30 sec. preview of a song if Spotify
        doesn't provide one, also assigns a different genre since iTunes uses
        more traditional genres, returns track metadata'''

    artist = artist.replace(" ","+")
    song = song.replace(" ","+")

    try:
        r = requests.get(f"https://itunes.apple.com/search?term={artist}+{song}&limit=1")
        content = json.loads(r.text)
        preview = content['results'][0]["previewUrl"]
        
        doc = requests.get(preview)
        with open(f"../data/audio_files_2/track_{track_id}.wav", "wb") as f:
            f.write(doc.content)

    except:
        pass

    
def get_mp3(track_id, properties):
    '''A function that takes an mp3 url, and writes it to the local
        directory "/tmp"'''
    if properties[2]:
        try:
            doc = requests.get(properties[2])
            with open(f'../data/audio_files_2/track_{track_id}.wav', 'wb') as f:
                f.write(doc.content)
        except:
            pass
        
    else:
        try:
            get_missing_url(track_id, properties[0], properties[1])
        except:
            pass

# %%
sample_ids = list(songs.keys())[:5]

sample = {s: songs[s] for s in sample_ids}
sample
# Out:
# {'3tjFYV6RSFtuktYl3ZtYcq': ('24kGoldn',
#   'Mood (feat. Iann Dior)',
#   'https://p.scdn.co/mp3-preview/45cb08fdb67744ab7f1f172bb750e9c10415c37a?cid=b05f690e17ba4b758d92a214cfbc7f24'),
#  '27u7t9d7ZQoyjsCROHuZJ3': ('Clean Bandit',
#   'Tick Tock (feat. 24kGoldn)',
#   'https://p.scdn.co/mp3-preview/3d3f99ef7d4bea725a9bebc740cadf56e4f548bb?cid=b05f690e17ba4b758d92a214cfbc7f24'),
#  '6piAUJJQFD8oHDUr0b7l7q': ('24kGoldn',
#   'VALENTINO',
#   'https://p.scdn.co/mp3-preview/6347fe20d7716220bbe67c2c10ff091696719ca2?cid=b05f690e17ba4b758d92a214cfbc7f24'),
#  '68UW3plyDDNg1dkNIZRezJ': ('DVBBS',
#   'Tinted Eyes (feat. blackbear & 24kGoldn)',
#   'https://p.scdn.co/mp3-preview/d198eb9b7ca39a5a5589d8238ad416de7dcee032?cid=b05f690e17ba4b758d92a214cfbc7f24'),
#  '660BgHpKo1jhR9MMSFn7CF': ('24kGoldn',
#   'VALENTINO - Imanbek Remix',
#   'https://p.scdn.co/mp3-preview/9de5e13ff243c0e0fdbe52503a1250fcf6832de6?cid=b05f690e17ba4b758d92a214cfbc7f24')}

# %%
l = len(songs)

for i,(track_id,properties) in enumerate(songs.items()):
    get_mp3(track_id, properties)
    clear_output(wait=True)
    print(f"{i+1}/{l}")
# Out:
# 30794/182127

# %% [markdown]
# ### Cleaning the data sets
# Going to decide which columns to keep, thus deciding how to design the tables in the database.
#
# #### Librosa Dataset
# The librosa dataset doesn't need to be cleaned because I generated it myself, using a pipeline that generates the features I wanted. I only need to check for duplicates.

# %%
# checking for duplicates in librosa dataset
combined_librosa.duplicated().value_counts()
# Out:
# False    46721
# dtype: int64

# %% [markdown]
# #### Metadata
# The metadata dataset contains a lot of extra information that I won't necessarily use in the app. I'll save the original dataset as a csv just in case, but I'll only keep the necessary information in the database.

# %%
metadata_cols = ['track_id','track_name','artist','artist_id','genre_1','genre_2','genre_3']

track_metadata[metadata_cols]
# Out:
#                       track_id                                    track_name  \
# 0       6YDf6QV7QfCEo8O2dbWalK                                Real Love Baby
# 1       0qaWxVVd3KrP4WY27KWpIe                                    In a River
# 2       1yZMv2GMAibgLGsQiowZrt                             Nancy From Now On
# 3       2eg2gvPXuwZ9FyrPaLgrXi       Chateau Lobby #4 (in C for Two Virgins)
# 4       0wzruvvN7f5wu39aFcjTMw              Hollywood Forever Cemetery Sings
# ...                        ...                                           ...
# 230451  6jVVnTIC1zHFFdn2rBOE2g  This Must Be the Place (Naive Melody) - Live
# 230452  3xJ8siSD7r5mDqLNtQ5CPf                              A Soft Seduction
# 230453  6Mc0SvjQ2By4ZJWdF77M2C                             Dance on Vaseline
# 230454  392cd1euczCOcZAs0SvvZS           The Last Emperor (Main Title Theme)
# 230455  4MrwM9vGNeVKjIEtyZ2sQT                                  One Fine Day
#
#                    artist               artist_id  genre_1      genre_2  \
# 0       Father John Misty  2kGBy2WHvF0VdZyqiVCkDT  art pop  chamber pop
# 1                  Rostam  04XggbrM51GcFPTxBYtRXT  art pop  chamber pop
# 2       Father John Misty  2kGBy2WHvF0VdZyqiVCkDT  art pop  chamber pop
# 3       Father John Misty  2kGBy2WHvF0VdZyqiVCkDT  art pop  chamber pop
# 4       Father John Misty  2kGBy2WHvF0VdZyqiVCkDT  art pop  chamber pop
# ...                   ...                     ...      ...          ...
# 230451        David Byrne  20vuBdFblWUo2FCOvUzusB  art pop     art punk
# 230452        David Byrne  20vuBdFblWUo2FCOvUzusB  art pop     art punk
# 230453        David Byrne  20vuBdFblWUo2FCOvUzusB  art pop     art punk
# 230454        David Byrne  20vuBdFblWUo2FCOvUzusB  art pop     art punk
# 230455        David Byrne  20vuBdFblWUo2FCOvUzusB  art pop     art punk
#
#            genre_3
# 0       freak folk
# 1        indie pop
# 2       freak folk
# 3       freak folk
# 4       freak folk
# ...            ...
# 230451    art rock
# 230452    art rock
# 230453    art rock
# 230454    art rock
# 230455    art rock
#
# [230456 rows x 7 columns]

# %% [markdown]
# #### Spotify Features

# %%
cols = ['id','danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo']

spotify_features[cols]
# Out:
#                             id  danceability  energy  loudness  speechiness  \
# 0       0Tbgn7Ocm54WoqJUsIlfp4         0.644   0.912    -6.072       0.0384
# 1       1XibR7VrDllfBz6yuTndmb         0.696   0.623    -7.600       0.1260
# 2       3tjFYV6RSFtuktYl3ZtYcq         0.700   0.722    -3.558       0.0369
# 3       27u7t9d7ZQoyjsCROHuZJ3         0.779   0.705    -3.895       0.0344
# 4       6piAUJJQFD8oHDUr0b7l7q         0.747   0.717    -4.841       0.1790
# ...                        ...           ...     ...       ...          ...
# 200001  6jVVnTIC1zHFFdn2rBOE2g         0.709   0.490   -13.565       0.1520
# 200002  3xJ8siSD7r5mDqLNtQ5CPf         0.523   0.215   -15.376       0.0274
# 200003  6Mc0SvjQ2By4ZJWdF77M2C         0.727   0.840    -9.915       0.0650
# 200004  392cd1euczCOcZAs0SvvZS         0.400   0.208   -16.351       0.0311
# 200005  4MrwM9vGNeVKjIEtyZ2sQT         0.451   0.662    -6.641       0.0284
#
#         acousticness  instrumentalness  liveness  valence    tempo
# 0            0.00301          0.657000    0.0782    0.222  126.011
# 1            0.01750          0.000091    0.1430    0.573  173.951
# 2            0.22100          0.000000    0.2720    0.756   90.989
# 3            0.36900          0.000008    0.1240    0.946  101.022
# 4            0.19900          0.000000    0.1320    0.523  150.965
# ...              ...               ...       ...      ...      ...
# 200001       0.43100          0.000013    0.9460    0.745  117.158
# 200002       0.87000          0.003780    0.1060    0.346   99.057
# 200003       0.01040          0.038900    0.1000    0.460  111.013
# 200004       0.74400          0.775000    0.2670    0.551  180.243
# 200005       0.18700          0.000195    0.1140    0.436  151.821
#
# [200006 rows x 10 columns]
